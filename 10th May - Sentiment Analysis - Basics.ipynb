# %%
import nltk

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('good')
# Out:
# {'compound': 0.4404, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0}

# %%
sia.polarity_scores('very good')
# Out:
# {'compound': 0.4927, 'neg': 0.0, 'neu': 0.238, 'pos': 0.762}

# %%
sia.polarity_scores('good and awesome')
# Out:
# {'compound': 0.7906, 'neg': 0.0, 'neu': 0.125, 'pos': 0.875}

# %%
sia.polarity_scores('not good')

# %%
sia.polarity_scores('worst')

# %%
sia.polarity_scores('not bad')

# %%
sia.polarity_scores('good awesome')

# %%
sia.polarity_scores('gud')
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
sia.polarity_scores('grt')
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
sia.polarity_scores('gr8')
# Out:
# {'compound': 0.5719, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0}

# %%
sia.polarity_scores('lol')
# Out:
# {'compound': 0.4215, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0}

# %%
sia.polarity_scores(':)')
# Out:
# {'compound': 0.4588, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0}

# %%
sia.polarity_scores(':(')
# Out:
# {'compound': -0.4404, 'neg': 1.0, 'neu': 0.0, 'pos': 0.0}

# %%
sia.polarity_scores(':<')
# Out:
# {'compound': -0.4767, 'neg': 1.0, 'neu': 0.0, 'pos': 0.0}

# %%
sia.polarity_scores('this was the best movie of my life')
# Out:
# {'compound': 0.6369, 'neg': 0.0, 'neu': 0.625, 'pos': 0.375}

# %%
sia.polarity_scores('it was better to be at home instead of watching that movie')
# Out:
# {'compound': 0.4404, 'neg': 0.0, 'neu': 0.791, 'pos': 0.209}

# %%
sia.polarity_scores('it was better to be at home instead of watching that boring movie')
# Out:
# {'compound': 0.1531, 'neg': 0.142, 'neu': 0.679, 'pos': 0.179}
