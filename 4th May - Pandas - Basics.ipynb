# %%
import pandas as pd

# %%
data = pd.read_csv("/content/nba.csv")  ## ctrl + v to paste
data

# %%
len(data)

# %%
type(data)

# %%
data.info()

# %%
data.head()  ### display first 5 rows

# %%
data.head(3)  ### display first 3 rows

# %%
data.tail()  ## display bottom 5 rows

# %%
data.sample()  ## a single random row

# %%
data.sample(3,random_state=0)
# Out:
#              Name              Team  ...           College      Salary
# 164  Derrick Rose     Chicago Bulls  ...           Memphis  20093064.0
# 229  Jeremy Evans  Dallas Mavericks  ...  Western Kentucky   1100602.0
# 311  Kirk Hinrich     Atlanta Hawks  ...            Kansas   2854940.0
#
# [3 rows x 9 columns]

# %%
### Working With Null Values

# %%
data.isnull().sum()  ## count of null values in each columns
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
### Remove null value
data_new = data.dropna(axis=0)  ## default is 0(row)

# %%
len(data_new)

# %%
data_new.isnull().sum()

# %%
data_new = data.dropna(axis=1)  ## columns

# %%
data_new = data.dropna(how='all')  ## default is 'any'

# %%
len(data_new)

# %%
data_new = data.dropna(subset=['College'])   ## default = NONE

# %%
len(data_new)

# %%
### Replace The null values
data.isnull().sum()

# %%
data_new = data.dropna(how='all')

# %%
data_new.isnull().sum()

# %%
data_new.info()

# %%
data_new['College'] = data_new['College'].fillna('No College')

# %%
avg_sal = round(data_new['Salary'].mean(),2)
avg_sal

# %%
data_new['Salary'] = data_new['Salary'].fillna(avg_sal)

# %%
data_new.isnull().sum()

# %%
data_new.head()
# Out:
#             Name            Team  Number  ... Weight            College      Salary
# 0  Avery Bradley  Boston Celtics     0.0  ...  180.0              Texas  7730337.00
# 1    Jae Crowder  Boston Celtics    99.0  ...  235.0          Marquette  6796117.00
# 2   John Holland  Boston Celtics    30.0  ...  205.0  Boston University  4842684.11
# 3    R.J. Hunter  Boston Celtics    28.0  ...  185.0      Georgia State  1148640.00
# 4  Jonas Jerebko  Boston Celtics     8.0  ...  231.0         No College  5000000.00
#
# [5 rows x 9 columns]

# %%
### Delete Row
data_new = data_new.drop([1,3],axis=0)
data_new

# %%
### Delete Columns
data_new = data_new.drop(["Name","Position"],axis=1)
data_new.head()
# Out:
#              Team  Number   Age Height  Weight            College       Salary
# 0  Boston Celtics     0.0  25.0    6-2   180.0              Texas   7730337.00
# 2  Boston Celtics    30.0  27.0    6-5   205.0  Boston University   4842684.11
# 4  Boston Celtics     8.0  29.0   6-10   231.0         No College   5000000.00
# 5  Boston Celtics    90.0  29.0    6-9   240.0         No College  12000000.00
# 6  Boston Celtics    55.0  21.0    6-8   235.0                LSU   1170960.00

# %%
#### loc and iloc  -- Get the data of any particular row

# %%
data_new.head()

# %%
data_new.iloc[2]  ### relative index is passed

# %%
data_new.loc[4]  ## index value

# %%
data_new.iloc[10:51]

# %%
data_new.iloc[10:51][["College","Salary","Age"]]

# %%
data_new.iloc[10:51,5:7]

# %%
data_new.head()
