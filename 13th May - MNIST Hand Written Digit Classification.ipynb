# %%
import keras as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
mnist = tf.datasets.mnist

# %%
(xtrain,ytrain),(xtest,ytest) = mnist.load_data()

# %%
len(xtrain)

# %%
len(xtest)

# %%
xtrain[5]

# %%
ytrain[5]

# %%
ytrain[59999]

# %%
plt.imshow(xtrain[59999],cmap='gray')
plt.show()

# %%
### Neural Network
model = tf.models.Sequential()  ## blank model
model.add(tf.layers.Flatten())   ### input layer
model.add(tf.layers.Dense(784,activation='relu'))    ## 28x28   ## hidden
model.add(tf.layers.Dense(10,activation="softmax"))  ## output layer
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
### Scale the data
xtrain_scaled = xtrain/255
xtest_scaled = xtest/255

# %%
xtrain_scaled[5]

# %%
## Train the model
model.fit(xtrain_scaled,ytrain,epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3227 - accuracy: 0.9035
# Epoch 2/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0792 - accuracy: 0.9758
# Epoch 3/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0477 - accuracy: 0.9846
# Epoch 4/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0319 - accuracy: 0.9897
# Epoch 5/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0216 - accuracy: 0.9927
# Epoch 6/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0182 - accuracy: 0.9942
# Epoch 7/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0136 - accuracy: 0.9953
# Epoch 8/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0119 - accuracy: 0.9961
# Epoch 9/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0125 - accuracy: 0.9959
# Epoch 10/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0088 - accuracy: 0.9972
# Epoch 11/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0081 - accuracy: 0.9974
# Epoch 12/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0087 - accuracy: 0.9972
# Epoch 13/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0079 - accuracy: 0.9974
# Epoch 14/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0067 - accuracy: 0.9980
# Epoch 15/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0095 - accuracy: 0.9966

# %%
ypred = model.predict(xtest_scaled)

# %%
ypred[5]

# %%
np.argmax(ypred[5])
# Out:
# 1

# %%
ytest[5]
# Out:
# 1

# %%
model.evaluate(xtest_scaled,ytest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,np.argmax(ypred,axis=1))
cm

# %%
ytest
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
np.argmax(ypred,axis=1)
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
import cv2
# reading of image
img = cv2.imread("/content/3.png",0)
## preprocessing of image
img = cv2.resize(img,(28,28))
img = cv2.bitwise_not(img)
img = img/255
plt.imshow(img,cmap='gray')
plt.show()

# %%
img.shape

# %%
np.argmax(model.predict(np.array([[img]])))
# Out:
# 3
