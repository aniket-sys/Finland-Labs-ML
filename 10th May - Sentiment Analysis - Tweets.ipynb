# %%
import nltk
import pandas as pd

# %%
nltk.download("vader_lexicon")

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
data = pd.read_csv("/content/twitter_data.csv",encoding="latin")
data.head()

# %%
data.info()

# %%
from textblob import TextBlob

# %%
a = TextBlob('good')
a.sentiment

# %%
a = TextBlob('bad')
a.sentiment

# %%
a = TextBlob('best')
a.sentiment
